# %% [markdown]
# # 04. Attention-Based Seq2Seq + LSTM Training
#
# This notebook will be used to train the Attention-based Sequence-to-Sequence model with LSTM encoder-decoder (designed to run on Google Colab GPU).
