# %% [markdown]
# # 02. Data Preprocessing and Tokenization
#
# This notebook will handle text cleaning, normalization, Amharic/English tokenization, vocabulary building, and train/val/test splitting.
