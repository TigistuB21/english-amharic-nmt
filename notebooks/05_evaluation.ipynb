# %% [markdown]
# # 05. Model Evaluation and Comparison
#
# This notebook will be used to benchmark BLEU, chrF, test loss, latency, parameters, inspect translation examples, and generate attention weight heatmaps.
